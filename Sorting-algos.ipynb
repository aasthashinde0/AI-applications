# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr



def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

def print_array(arr):
    for i in range(len(arr)):
        print(arr[i], end=" ")
    print()

def choose_sort_algorithm(arr):
    n = len(arr)

    if n < 10:
        print("Reasoning Rule: Small input → Use Insertion Sort")
        return insertion_sort(arr)
        
    elif n < 100:
        print("Reasoning Rule: Medium input → Use Bubble Sort")
        return bubble_sort(arr)
        
    elif n>100 :
        print("Reasoning Rule: Large input → Use Quick Sort")
        return quick_sort(arr)
    else:
        print(" Default → Using Selection Sort")
        selection_sort(arr)

    return arr

# Main Function
def main():
    arr = [34, 2, 78, 12, 45, 22]
    print("Original array:", arr)

    sorted_arr = choose_sort_algorithm(arr.copy())
    print("Sorted array:", sorted_arr)

main()
# Out:
# Original array: [34, 2, 78, 12, 45, 22]
# Reasoning Rule: Small input → Use Insertion Sort
# Sorted array: [2, 12, 22, 34, 45, 78]
